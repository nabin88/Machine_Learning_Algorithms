# %% [markdown]
# # Gradient descent algorithm using Python
#
# Gradient descent is one of the most common optimization algorithms used in machine learning aided Linear Regression. A general equation of a straight line is $y = mx + b$. Let's say a data set has multiple features (i.e. multiple $x$ values), then in order to get a line of best fit, we need to optimize the parameters $m$ and $b$ that will minimize the 'mean square errors'. Mean square error (MSE) is also called 'cost' function (mostly in data science and machine learning).
#
# Mean square errors or the cost function (denoted by C from now on) is defined as:
#
# \begin{equation}
# C = \frac{1}{N} \sum_i (y_i - y_{i,predicted})^2 \tag{1}
# \end{equation}
#
# where $y_i$ are the real values for your target variable and $y_{i,predicted}$ are the values predicted for the $i^{th}$ target variable by your model, and N is the number x's in your data. Since, $y_{i,predicted} = m_ix + b_i$, we can rewrite the above equation as
#
# \begin{equation}
# C = \frac{1}{n} \sum_i (y_i - (m_ix_i + b_i))^2 \tag{2}
# \end{equation}
#
# Our goal is to find the parameters $m_i$ and $b_i$ that will minimize the value of C. It is a function of two parameters $m_i$ and $b_i$ in this case, i.e., C = C($m_i$,$b_i$). We take the partial derivative of C with respect to $m_i$ and $b_i$. Let's start by taking the partial derivative of MSE with respect to $m_i$:
#
# \begin{equation}
# \frac{\partial C}{\partial m_i} = - x_i \frac{2}{n} (y_i - (m_ix_i + b_i)) \tag{3}
# \end{equation}
#
# and when we take the partial derivative of C with respect to $b_i$, we get
#
# \begin{equation}
# \frac{\partial C}{\partial b_i} = -\frac{2}{n} (y_i - (m_ix_i + b_i)) \tag{4}
# \end{equation}
#
# Now, you should take the following steps in your algorithm:
# - Define the cost functions.
# - Initialize the calculations by choosing some $m_i$ and $b_i$.
# - Generate $y_{i,predicted}$ using these values and compute cost function.
# - Minimize that cost function with respect to $m_i$ and $b_i$ using the equations (3) and (4). These are your $m_{present\,value}$ and $b_{present\,value}$ in the equations below.
# - Now, you need to update the values of $m_i$ and $b_i$. It is done by choosing proper 'learning rate'.
#
# \begin{equation}
# m_{updated} = m_{present\,value} - (learning\,rate) \,m_i \tag{5} \\
# b_{updated} = b_{present\,value} - (learning\,rate) \,b_i
# \end{equation}
#
# - Compute updated cost function, updated m and b as above.
# - It takes multiple iterations to reach the 'global minima' of the function. Try different number of iterations according to your need.
# - Since the goal is to reduce the cost function in order to reach the global minima, your cost function should decrease after each iterations.
#
# Now, let's code the algorithm.

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
def grad_descent(x,y,n_iterations,learning_rate):
    N = len(x)
    m_present = 0
    b_present = 0
    for i in range(n_iterations):
        y_predicted = m_present * x + b_present
        C = (1/N)*sum((y-y_predicted)**2) # equation (2)
        m_present = m_present - learning_rate*(-(2/N)*sum(x*(y-y_predicted))) # equation (5)
        b_present = b_present - learning_rate*(-(2/N)*sum(y-y_predicted)) # equation (5)
        print("The cost is {} after {} iteration(s).".format(C, i))

# %%
# Example
x = np.linspace(0,10,40)
noise = np.random.default_rng()
y = [((i*2)+noise.random()) for i in x]

# %%
# Let's see how our x and y look like
plt.scatter(x,y)
plt.xlabel('x', fontsize=12)
plt.ylabel('y', fontsize=12)
plt.show()

# %%
# Let's see how the algorithm perfoms
grad_descent(x,y,150,0.0005)
# Out:
# The cost is 144.92213749463102 after 0 iteration(s).
# The cost is 135.09937137179597 after 1 iteration(s).
# The cost is 125.94281329983107 after 2 iteration(s).
# The cost is 117.40727912846167 after 3 iteration(s).
# The cost is 109.45064922673151 after 4 iteration(s).
# The cost is 102.03366063846909 after 5 iteration(s).
# The cost is 95.11971333436887 after 6 iteration(s).
# The cost is 88.67468960461527 after 7 iteration(s).
# The cost is 82.66678570081937 after 8 iteration(s).
# The cost is 77.06635489648482 after 9 iteration(s).
# The cost is 71.84576119156513 after 10 iteration(s).
# The cost is 66.97924293919999 after 11 iteration(s).
# The cost is 62.442785721679016 after 12 iteration(s).
# The cost is 58.21400384832437 after 13 iteration(s).
# The cost is 54.27202989052845 after 14 iteration(s).
# The cost is 50.59741170884383 after 15 iteration(s).
# The cost is 47.172016463992634 after 16 iteration(s).
# The cost is 43.97894113812612 after 17 iteration(s).
# The cost is 41.002429124790275 after 18 iteration(s).
# The cost is 38.22779247600043 after 19 iteration(s).
# The cost is 35.64133942274331 after 20 iteration(s).
# The cost is 33.23030681124773 after 21 iteration(s).
# The cost is 30.982797121621935 after 22 iteration(s).
# The cost is 28.88771975806879 after 23 iteration(s).
# The cost is 26.934736320967517 after 24 iteration(s).
# The cost is 25.114209590760865 after 25 iteration(s).
# The cost is 23.417155971901895 after 26 iteration(s).
# The cost is 21.835201162189573 after 27 iteration(s).
# The cost is 20.36053882873766 after 28 iteration(s).
# The cost is 18.98589208665855 after 29 iteration(s).
# The cost is 17.70447759037384 after 30 iteration(s).
# The cost is 16.509972060355775 after 31 iteration(s).
# The cost is 15.396481080121413 after 32 iteration(s).
# The cost is 14.358510009504778 after 33 iteration(s).
# The cost is 13.390936870674587 after 34 iteration(s).
# The cost is 12.488987073100555 after 35 iteration(s).
# The cost is 11.64820985274522 after 36 iteration(s).
# The cost is 10.864456309217745 after 37 iteration(s).
# The cost is 10.13385893251129 after 38 iteration(s).
# The cost is 9.452812518296005 after 39 iteration(s).
# The cost is 8.81795637759192 after 40 iteration(s).
# The cost is 8.226157753033064 after 41 iteration(s).
# The cost is 7.674496359888401 after 42 iteration(s).
# The cost is 7.160249975555221 after 43 iteration(s).
# The cost is 6.680881006414708 after 44 iteration(s).
# The cost is 6.234023965762002 after 45 iteration(s).
# The cost is 5.817473801019227 after 46 iteration(s).
# The cost is 5.429175012630494 after 47 iteration(s).
# The cost is 0.21241650016030392 after 101 iteration(s).
# The cost is 0.20425494302663194 after 102 iteration(s).
# The cost is 0.19664667685952872 after 103 iteration(s).
# The cost is 0.1895541759973393 after 104 iteration(s).
# The cost is 0.18294245987688842 after 105 iteration(s).
# The cost is 0.1767789204175651 after 106 iteration(s).
# The cost is 0.17103316111271624 after 107 iteration(s).
# The cost is 0.16567684703432642 after 108 iteration(s).
# The cost is 0.16068356501081238 after 109 iteration(s).
# The cost is 0.15602869328796024 after 110 iteration(s).
# The cost is 0.1516892800298385 after 111 iteration(s).
# The cost is 0.14764393006012386 after 112 iteration(s).
# The cost is 0.1438726992849614 after 113 iteration(s).
# The cost is 0.14035699627636775 after 114 iteration(s).
# The cost is 0.13707949053053173 after 115 iteration(s).
# The cost is 0.13402402694830437 after 116 iteration(s).
# The cost is 0.13117554611586527 after 117 iteration(s).
# The cost is 0.12852000999218546 after 118 iteration(s).
# The cost is 0.1260443326365793 after 119 iteration(s).
# The cost is 0.12373631563451781 after 120 iteration(s).
# The cost is 0.12158458790304333 after 121 iteration(s).
# The cost is 0.11957854957875902 after 122 iteration(s).
# The cost is 0.11770831971149523 after 123 iteration(s).
# The cost is 0.11596468750554118 after 124 iteration(s).
# The cost is 0.11433906686783851 after 125 iteration(s).
# The cost is 0.11282345403884729 after 126 iteration(s).
# The cost is 0.11141038809700643 after 127 iteration(s).
# The cost is 0.1100929141418991 after 128 iteration(s).
# The cost is 0.1088645489744392 after 129 iteration(s).
# The cost is 0.10771924910472717 after 130 iteration(s).
# The cost is 0.10665138092970597 after 131 iteration(s).
# The cost is 0.10565569293345445 after 132 iteration(s).
# The cost is 0.10472728977293454 after 133 iteration(s).
# The cost is 0.10386160812132138 after 134 iteration(s).
# The cost is 0.1030543941497068 after 135 iteration(s).
# The cost is 0.10230168253605681 after 136 iteration(s).
# The cost is 0.1015997768978465 after 137 iteration(s).
# The cost is 0.10094523155180393 after 138 iteration(s).
# The cost is 0.10033483451076751 after 139 iteration(s).
# The cost is 0.09976559163373956 after 140 iteration(s).
# The cost is 0.09923471185093301 after 141 iteration(s).
# The cost is 0.09873959339089622 after 142 iteration(s).
# The cost is 0.09827781094175354 after 143 iteration(s).
# The cost is 0.09784710368320984 after 144 iteration(s).
# The cost is 0.09744536413025565 after 145 iteration(s).
# The cost is 0.09707062773352688 after 146 iteration(s).
# The cost is 0.09672106318499801 after 147 iteration(s).
# The cost is 0.09639496338116953 after 148 iteration(s).
# The cost is 0.09609073699915893 after 149 iteration(s).

# %% [markdown]
# We can see that with each iteration, the cost is decreasing and saturating towards the end. Choosing proper values of learning_rate and number of iterations play very important roles in gradient descent algorithms.
